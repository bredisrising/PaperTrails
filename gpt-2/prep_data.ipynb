# %%
import pickle

# %%
with open("./data.pkl", 'rb') as f:
    data = pickle.load(f)

# %%
import torch

# %%
tensors = [torch.tensor(row, dtype=torch.int16) for row in data]

# %%
import pickle

# %%
with open("vocab.pkl", "rb") as f:
    vocab = pickle.load(f)

# %%
vocab.keys()
# Out:
# dict_keys(['tokens', 'token_to_index', 'index_to_token'])
